# %% [markdown]
# # Assignment-1 (Ans-3)

# %% [markdown]
# ### Required libraries for Scrapping

# %%
#First we will import all the libraries required for web-scraping
#We will require two libraries for web-scraping:
    
   # 1. requests: This will be used to send get request to the web page server to get the source-code for the webpage
   # 2. BeautifulSoup: It will be used to prase the source code and to extract the required data from the parsed structure.

# %% [markdown]
# ### Import required libraries for scraping the data

# %%
# importing the required libraries

import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

# %%
# Downloading imdb top 100 hindi movie's data

url = 'https://www.imdb.com/list/ls063915608/?sort=list_order,asc&st_dt=&mode=detail&page=1'
response = requests.get('https://www.imdb.com/list/ls063915608/?sort=list_order,asc&st_dt=&mode=detail&page=1')

# %%
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content)
soup
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>TOP 100 Hindi Movies All Time - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
#       uex("ld", "LoadTitle", {wb: 1});
#     }
# </script>
# <link href="https://www.imdb.com/list/ls063915608/" rel="canonical"/>
# ...

# %%
import requests
from bs4 import BeautifulSoup

def get_topics_page():
    # TODO - add comments
    url = 'https://www.imdb.com/list/ls063915608/'
    response=requests.get(url)
    # check successfull response
    if response.status_code != 200:
        raise Exception(f'Failed to load page {url}')
    # Parse using BeautifulSoup
    doc = BeautifulSoup(response.text, 'html.parser')
    return doc

# %%
doc = BeautifulSoup(response.text, 'html.parser')

# %%
doc.find('title')
# Out:
# <title>TOP 100 Hindi Movies All Time - IMDb</title>

# %%
def get_movie_titles(doc):
    
    selection_class="lister-item-header"
    movie_title_tags=doc.find_all('h3',{'class':selection_class})
    movie_titles=[]

    for tag in movie_title_tags:
        title = tag.find('a').text
        movie_titles.append(title)
        
        
    return movie_titles

# %%
titles = get_movie_titles(doc)

# %%
titles[:100]
# Out:
# ['Rang De Basanti',
#  'Lagaan: Once Upon a Time in India',
#  'Dil Chahta Hai',
#  'Gangs of Wasseypur',
#  'Zindagi Na Milegi Dobara',
#  '3 Idiots',
#  'Swades: We, the People',
#  'Paan Singh Tomar',
#  'Salaam Bombay!',
#  'Bhaag Milkha Bhaag',
#  'A Wednesday',
#  'Barfi!',
#  'Dev.D',
#  'Gangs of Wasseypur',
#  'Taare Zameen Par',
#  'Munna Bhai M.B.B.S.',
#  'Vicky Donor',
#  'Drishyam',
#  'Hera Pheri',
#  'Andaz Apna Apna',
#  'Gangaajal',
#  'Once Upon a Time in Mumbaai',
#  'Raajneeti',
#  'Special Chabbis',
#  'Masaan',
#  'Ankhon Dekhi',
#  'Parched',
#  'Udaan',
#  'PK',
#  'Oye Lucky! Lucky Oye!',
#  'Ship of Theseus',
#  'Kahaani',
#  'Maqbool',
#  'Bandit Queen',
#  'Black Friday',
#  'Omkara',
#  'Queen',
#  'Shahid',
#  'The Lunchbox',
#  'Dangal',
#  'Chak De! India',
#  'Black',
#  'Guru',
#  'My Name Is Khan',
#  'Manjhi: The Mountain Man',
#  'Satya',
#  'Paa',
#  'Raincoat',
#  'The Legend of Bhagat Singh',
#  'Apaharan',
#  'OMG: Oh My God!',
#  'Shool',
# ...

# %%
def get_movie_year(doc):
    year_selector = "lister-item-year text-muted unbold"           
    movie_year_tags=doc.find_all('span',{'class':year_selector})
    movie_year_tagss=[]
    for tag in movie_year_tags:
        movie_year_tagss.append(tag.get_text().strip()[1:100])
    return movie_year_tagss

# %%
years = get_movie_year(doc)

# %%
years[:100]
# Out:
# ['2006)',
#  '2001)',
#  '2001)',
#  '2012)',
#  '2011)',
#  '2009)',
#  '2004)',
#  '2012)',
#  '1988)',
#  '2013)',
#  '2008)',
#  '2012)',
#  '2009)',
#  '2012)',
#  '2007)',
#  '2003)',
#  '2012)',
#  '2015)',
#  '2000)',
#  '1994)',
#  '2003)',
#  '2010)',
#  '2010)',
#  '2013)',
#  '2015)',
#  '2013)',
#  '2015)',
#  '2010)',
#  '2014)',
#  '2008)',
#  '2012)',
#  '2012)',
#  '2003)',
#  '1994)',
#  '2004)',
#  '2006)',
#  '2013)',
#  '2012)',
#  '2013)',
#  '2016)',
#  '2007)',
#  '2005)',
#  '2007)',
#  '2010)',
#  '2015)',
#  '1998)',
#  '2009)',
#  '2004)',
#  '2002)',
#  '2005)',
#  '2012)',
#  '1999)',
#  '2015)',
#  '2009)',
#  '1975)',
#  '2014)',
#  '2008)',
#  '1992)',
#  '2006)',
#  '2015)',
#  '2011)',
#  '1995)',
#  '2012)',
#  '2008)',
#  'I) (2002)',
#  '2007)',
#  'III) (2016)',
#  '2013)',
#  '2008)',
#  '2008)',
#  '2010)',
#  '2002)',
#  '1993)',
#  '2009)',
#  '2016)',
#  '2013)',
#  'I) (2013)',
#  '2015)',
#  '2008)',
#  '1999)',
#  '2013)',
#  '2013)',
# ...

# %%
def get_movie_url(doc):
    url_selector="lister-item-header"           
    movie_url_tags=doc.find_all('h3',{'class':url_selector})
    movie_url_tagss=[]
    base_url = 'https://www.imdb.com/'
    for tag in movie_url_tags:
        movie_url_tagss.append('https://www.imdb.com/' + tag.find('a')['href'])
    return movie_url_tagss

# %%
urls = get_movie_url(doc)

# %%
urls[:100]
# Out:
# ['https://www.imdb.com//title/tt0405508/',
#  'https://www.imdb.com//title/tt0169102/',
#  'https://www.imdb.com//title/tt0292490/',
#  'https://www.imdb.com//title/tt1954470/',
#  'https://www.imdb.com//title/tt1562872/',
#  'https://www.imdb.com//title/tt1187043/',
#  'https://www.imdb.com//title/tt0367110/',
#  'https://www.imdb.com//title/tt1620933/',
#  'https://www.imdb.com//title/tt0096028/',
#  'https://www.imdb.com//title/tt2356180/',
#  'https://www.imdb.com//title/tt1280558/',
#  'https://www.imdb.com//title/tt2082197/',
#  'https://www.imdb.com//title/tt1327035/',
#  'https://www.imdb.com//title/tt1954470/',
#  'https://www.imdb.com//title/tt0986264/',
#  'https://www.imdb.com//title/tt0374887/',
#  'https://www.imdb.com//title/tt2317337/',
#  'https://www.imdb.com//title/tt4430212/',
#  'https://www.imdb.com//title/tt0242519/',
#  'https://www.imdb.com//title/tt0109117/',
#  'https://www.imdb.com//title/tt0373856/',
#  'https://www.imdb.com//title/tt1395054/',
# ...

# %%
def get_movie_rating(doc):
    rating_selector="ipl-rating-star small"            
    movie_rating_tags=doc.find_all('div',{'class':rating_selector})
    movie_rating_tagss=[]
    for tag in movie_rating_tags:
        movie_rating_tagss.append(tag.get_text().strip())
    return movie_rating_tagss

# %%
ratings = get_movie_rating(doc)

# %%
ratings[:100]
# Out:
# ['8.1',
#  '8.1',
#  '8.1',
#  '8.2',
#  '8.2',
#  '8.4',
#  '8.2',
#  '8.2',
#  '7.9',
#  '8.2',
#  '8.1',
#  '8.1',
#  '7.9',
#  '8.2',
#  '8.4',
#  '8.1',
#  '7.8',
#  '8.2',
#  '8.1',
#  '8',
#  '7.8',
#  '7.4',
#  '7.1',
#  '8',
#  '8.1',
#  '7.9',
#  '7.5',
#  '8.1',
#  '8.1',
#  '7.7',
#  '8',
#  '8.1',
#  '8',
#  '7.5',
#  '8.4',
#  '8.1',
#  '8.1',
#  '8.2',
#  '7.8',
#  '8.3',
#  '8.1',
#  '8.1',
#  '7.7',
#  '7.9',
#  '8',
#  '8.3',
#  '7.1',
#  '7.7',
#  '8.2',
#  '7.4',
#  '8.1',
#  '7.7',
#  '8.1',
#  '7.6',
#  '8.1',
#  '8',
#  '7.7',
#  '8.2',
#  '8',
#  '7.5',
#  '7.7',
#  '8',
#  '7.8',
#  '7.3',
#  '7.5',
#  '7.9',
#  '8.1',
#  '7.9',
#  '7.7',
#  '7.5',
#  '7.4',
#  '8',
#  '7.8',
#  '8',
#  '7.7',
#  '7.6',
#  '7.4',
#  '8',
#  '6.9',
#  '8.1',
#  '7.8',
#  '7.6',
#  '7.2',
#  '7.9',
#  '7.4',
#  '7.8',
#  '7.6',
#  '7.4',
#  '7.1',
#  '7.8',
#  '7.4',
#  '7.5',
#  '7.3',
#  '7.8',
#  '7.6',
#  '7.4',
#  '7.4',
#  '7.8',
#  '7.6',
#  '7.7']

# %%
movie_DF = pd.DataFrame({'Name of movie': titles, 'Year of release': years, 'Movie rating': ratings,'Movie URL':url})

# %%
movie_DF
# Out:
#                         Name of movie Year of release Movie rating  \
# 0                     Rang De Basanti           2006)          8.1
# 1   Lagaan: Once Upon a Time in India           2001)          8.1
# 2                      Dil Chahta Hai           2001)          8.1
# 3                  Gangs of Wasseypur           2012)          8.2
# 4            Zindagi Na Milegi Dobara           2011)          8.2
# ..                                ...             ...          ...
# 95                            Dhamaal           2007)          7.4
# 96             Golmaal: Fun Unlimited           2006)          7.4
# 97                            Aligarh           2015)          7.8
# 98                              Earth           1998)          7.6
# 99                      Kapoor & Sons           2016)          7.7
#
#                                             Movie URL
# 0   https://www.imdb.com/list/ls063915608/?sort=li...
# ...

# %% [markdown]
# ### Thank You

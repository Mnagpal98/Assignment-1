# %% [markdown]
# # Assignment-1 (Ans-6)

# %% [markdown]
# #### 6) Write a python program to scrape cricket rankings from icc-cricket.com. You have to scrape:
# a) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.
# b) Top 10 women’s ODI Batting players along with the records of their team and rating.
# c) Top 10 women’s ODI all-rounder along with the records of their team and rating.

# %% [markdown]
# ### First install Libraries

# %%
# First we will import all the libraries required for web-scraping
# We will require two libraries for web-scraping:
   # 1. requests: This will be used to send get request to the web page server to get the source-code for the webpage
        
    #2. BeautifulSoup: It will be used to prase the source code and to extract the required data from the parsed structure.

# %%
# importing the required libraries

import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np

# %%
# Downloading the list of Cricket Ranking

url = 'https://www.icc-cricket.com/rankings/womens/team-rankings/odi'
page = requests.get('https://www.icc-cricket.com/rankings/womens/team-rankings/odi')
soup = BeautifulSoup(page.content, 'html.parser')

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="ICC Women's ODI Team Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for test match cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Women's ODI Team Rankings | ICC" property="og:title"/>
# ...

# %% [markdown]
# ###### 6(a)

# %%
a=soup.find_all('tr')[1:11]
a
for i in a:
    print(i.text.split())
# Out:
# ['1', 'Australia', 'AUS', '18', '3,061', '170']
# ['2', 'South', 'Africa', 'SA', '26', '3,098', '119']
# ['3', 'England', 'ENG', '25', '2,904', '116']
# ['4', 'India', 'IND', '27', '2,820', '104']
# ['5', 'New', 'Zealand', 'NZ', '24', '2,425', '101']
# ['6', 'West', 'Indies', 'WI', '24', '2,334', '97']
# ['7', 'Bangladesh', 'BAN', '12', '932', '78']
# ['8', 'Thailand', 'THA', '8', '572', '72']
# ['9', 'Pakistan', 'PAK', '24', '1,519', '63']
# ['10', 'Sri', 'Lanka', 'SL', '8', '353', '44']

# %%
url = 'https://www.icc-cricket.com/rankings/womens/player-rankings/odi'
page = requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi')
soup = BeautifulSoup(page.content, 'html.parser')

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="ICC Women's ODI Player Rankings | ICC" name="twitter:title"/>
# <meta content="website" property="og:type"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
# <meta content="@icc" property="twitter:site"/>
# <meta content="Official International Cricket Council rankings for ODI match cricket players. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
# <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# <meta content="ICC Women's ODI Player Rankings | ICC" property="og:title"/>
# ...

# %% [markdown]
# ###### 6(b)

# %%
b1=soup.find_all('a',class_='rankings-block__banner-link')[0:1]
b1
for i in b1:
    print(i.text.split())
# Out:
# ['1', '(0)', 'Alyssa', 'Healy', 'AUS', '785']

# %%
b2=soup.find_all('tr')[1:10]
b2
for i in b2:
    print(i.text.split())
# Out:
# ['2', '(0)', 'Beth', 'Mooney', 'AUS', '749']
# ['3', '(0)', 'Laura', 'Wolvaardt', 'SA', '732']
# ['4', '(0)', 'Natalie', 'Sciver', 'ENG', '725']
# ['5', '(0)', 'Harmanpreet', 'Kaur', 'IND', '716']
# ['6', '(0)', 'Smriti', 'Mandhana', 'IND', '714']
# ['7', '(0)', 'Meg', 'Lanning', 'AUS', '710']
# ['8', '(0)', 'Rachael', 'Haynes', 'AUS', '701']
# ['9', '(0)', 'Amy', 'Satterthwaite', 'NZ', '661']
# ['10', '(0)', 'Chamari', 'Athapaththu', 'SL', '655']

# %% [markdown]
# ##### 6(c)

# %%
c1=soup.find_all('a',class_='rankings-block__banner-link')[1:2]
c1
for i in c1:
    print(i.text.split())
# Out:
# ['1', '(0)', 'Sophie', 'Ecclestone', 'ENG', '739']

# %%
c2=soup.find_all('tr')[11:20]
c2
for i in c2:
    print(i.text.split())
# Out:
# ['2', '(0)', 'Jess', 'Jonassen', 'AUS', '725']
# ['3', '(0)', 'Megan', 'Schutt', 'AUS', '722']
# ['4', '(0)', 'Shabnim', 'Ismail', 'SA', '722']
# ['5', '(0)', 'Jhulan', 'Goswami', 'IND', '698']
# ['6', '(0)', 'Hayley', 'Matthews', 'WI', '671']
# ['7', '(0)', 'Kate', 'Cross', 'ENG', '657']
# ['8', '(0)', 'Ayabonga', 'Khaka', 'SA', '634']
# ['9', '(0)', 'Rajeshwari', 'Gayakwad', 'IND', '617']
# ['10', '(0)', 'Marizanne', 'Kapp', 'SA', '598']

# %% [markdown]
# ##### Thank You
